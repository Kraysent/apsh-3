# %% [markdown]
# <div class="alert alert-block alert-warning" style="margin-top: 20px">
#
# <font size=4>**Задание 1**</font>
#
# Построить на графике площадь под графиком функции `y = sin(x) + 1` на промежутке от 0 до $2\pi$.
#
# Площадь под графиком функции $f(x)$ в точке $x$ можно считать как сумму
#
# $$
# \sum_{i=0}^{x_i > x} f(x_i) (x_i - x_{i-1})
# $$
#
# Это эквивалентно сумме прямоугольников:
#
# ![](images/integral.png)
#
# </div>

# %%
...

# %% [markdown]
# <div class="alert alert-block alert-warning" style="margin-top: 20px">
#
# <font size=4>**Задание 2**</font>
#
# Построить график численной производной функции $y = 2 x ^ 3 + x - 5$ на промежутке от -5 до 5. Численную производную функции $f(x)$ в точке $x$ можно считать как
#
# $$
# f'(x) \approx \frac{f(x_i) - f(x_{i-1})}{x_i - x_{i-1}}
# $$
#
#
# </div>

# %%
...

# %% [markdown]
# <div class="alert alert-block alert-warning" style="margin-top: 20px">
#
# <font size=4>**Задание 3**</font>
#
# Дана функция
#
# $$
# y = \sin(2x) + 0.5 \cdot \cos(5x) + \sin(x) + 2
# $$
#
# На промежутке от $-2\pi$ до $2\pi$ численно найти x-координаты её локальных максимумов и отметить их на оси x вертикальными линиями.
#
# </div>

# %%
...
