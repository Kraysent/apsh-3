# %% [markdown]
# <div class="alert alert-block alert-warning" style="margin-top: 20px">
#
# <font size=4>**Задание 1**</font>
#
# Дана таблица `leda_data.csv`, содержащая данные о геометрии и красных смещениях для PGC-объектов из базы данных HyperLEDA. Ваша задача - отфильтровать только строки, не содержащие пустот среди данных всех столбцов и сохранить их в файл при помощи функции `write_csv` из `pandas`. Менять содержимое столбцов не нужно.
#
# Пример:
# ```python
# df.to_csv("myfile.csv")
# ```
#
# </div>

# %%
...

# %% [markdown]
# <div class="alert alert-block alert-warning" style="margin-top: 20px">
#
# <font size=4>**Задание 2**</font>
#
# В вашем файле из задания выше есть повторения среди PGC. Ваша задача - сделать таблицу с теми же столбцами, но так, чтобы каждый PGC-номер в ней содержался не более одного раза. Среди красных смещений для одного и того же номера выбрать среднее, а среди данных геометрии (a, e_a, b, e_b, pa, e_pa) выбрать строку с наименьшей относительной ошибкой по формуле `(e_a/a) ** 2 + (e_b/b) ** 2 + (e_pa/pa) ** 2`. Результирующую таблицу сохранить в файл.
#
# Обратите внимание: в данных геометрии должны быть данные **строки с наименьшей ошибкой**. Сами данные геометрии между разными строками не должны перемешаться.
#
# Итоговый файл должен содержать тот же набор столбцов, что и оригинальный.
#
# </div>

# %%
...

# %% [markdown]
# <div class="alert alert-block alert-warning" style="margin-top: 20px">
#
# <font size=4>**Задание 3**</font>
#
# Несколько шагов:
#
# 1. В таблицу из задания выше добавьте столбец для отношения большой и малой полуоси: ratio = b / a
# 2. Выберите 20 случайных объектов из всей таблицы
# 3. Посчитайте среднее красное смещение и среднее отношение полуосей
# 4. Сохраните его в список
# 5. Повторите шаги 2-5 50 раз
# 6. Постройте график распределения обоих величин при помощи `plt.hist`. Насколько он широкий? О чём это говорит?
#
# </div>

# %%
...
