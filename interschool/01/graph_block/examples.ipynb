# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [1, 2, 4, 8, 16]

plt.plot(x, y, color="blue", linewidth=3)
plt.grid(True)
plt.title("Текст")
# Out:
# Text(0.5, 1.0, 'Текст')

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [5, 3, 4, 2, 1]

plt.plot(x, y, linestyle="--", marker="o", color="green", linewidth=2)
plt.grid(True)
plt.title("Прерывистая с точками и подписями")
plt.xlabel("Горизонтальная подпись, секунды")
plt.ylabel("Вертикальная подпись, метры")
# Out:
# Text(0, 0.5, 'Вертикальная подпись, метры')

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [2, 3, 2, 3, 2]

plt.plot(x, y, linestyle=":", marker="s", color="purple", linewidth=2)
plt.grid(True, linestyle="--")
plt.title("Прерывистая с квадратами")
# Out:
# Text(0.5, 1.0, 'Прерывистая с квадратами')

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y1 = [0, 1, 2, 3, 4]
y2 = [0, 1, 4, 9, 16]

plt.plot(x, y1, linestyle="-", color="black", linewidth=2, label="Линейная")
plt.plot(x, y2, linestyle="--", color="red", marker="^", label="Квадратичная")

plt.grid(True)
plt.legend()
plt.title("Две линии")
# Out:
# Text(0.5, 1.0, 'Две линии')

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [3, 3, 4, 4, 5]

plt.plot(x, y, marker=".", linestyle="-", color="orange")

ax = plt.gca()
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

plt.grid(True)
plt.title("С линейками и без некоторых осей")
# Out:
# Text(0.5, 1.0, 'С линейками и без некоторых осей')

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [3, 3, 4, 4, 5]

plt.plot(x, y, marker="o", linestyle="None", color="blue")

plt.text(1, 3, "Пояснение")
plt.text(3.01, 4.1, "Ещё пояснение")
plt.grid(True)
plt.title("Без соединительных линий (но с текстом у точек)")
# Out:
# Text(0.5, 1.0, 'Без соединительных линий (но с текстом у точек)')
